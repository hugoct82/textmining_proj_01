# %% [markdown]
# #### Test de uso google colab desde el entorno de Visual Studio Code
#
# Este enfoque no prospera por falta de tiempo de implementación. Lo que se intentó lograr es usar lo recursos de la nube para correr modelos de clasificación que usan GPUs

# %%
from colabcode import ColabCode

ColabCode(port=10000, password="pass")
# Out:
# --2024-05-16 18:37:00--  https://code-server.dev/install.sh
# Resolviendo code-server.dev (code-server.dev)... 172.67.214.225, 104.21.16.171, 2606:4700:3031::ac43:d6e1, ...
# Conectando con code-server.dev (code-server.dev)[172.67.214.225]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 302 Found
# Ubicación: https://raw.githubusercontent.com/cdr/code-server/main/install.sh [siguiente]
# --2024-05-16 18:37:02--  https://raw.githubusercontent.com/cdr/code-server/main/install.sh
# Resolviendo raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Conectando con raw.githubusercontent.com (raw.githubusercontent.com)[185.199.110.133]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 15858 (15K) [text/plain]
# Guardando como: ‘install.sh’
#
#      0K .......... .....                                      100% 1,68M=0,009s
#
# ...

# %%
from colabcode import ColabCode

ColabCode(port=10000, password="pass")
# Out:
# --2024-05-16 18:30:10--  https://code-server.dev/install.sh
# Resolviendo code-server.dev (code-server.dev)... 104.21.16.171, 172.67.214.225, 2606:4700:3035::6815:10ab, ...
# Conectando con code-server.dev (code-server.dev)[104.21.16.171]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 302 Found
# Ubicación: https://raw.githubusercontent.com/cdr/code-server/main/install.sh [siguiente]
# --2024-05-16 18:30:11--  https://raw.githubusercontent.com/cdr/code-server/main/install.sh
# Resolviendo raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Conectando con raw.githubusercontent.com (raw.githubusercontent.com)[185.199.108.133]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 15858 (15K) [text/plain]
# Guardando como: ‘install.sh.3’
#
#      0K .......... .....                                      100% 85,4M=0s
#
# ...
