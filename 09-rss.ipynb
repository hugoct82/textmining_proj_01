# %%
import feedparser
import requests
import feedparser

def check_link(url):
    try:
        response = requests.head(url, allow_redirects=True, timeout=10)
        if response.status_code == 200:
            return True
        else:
            return False
    except requests.RequestException:
        return False

rss_url = "https://www.forbesargentina.com/"

# Parsear el feed
feed = feedparser.parse(rss_url)

# Verificar cada enlace en las entradas del feed
for entry in feed.entries:
    print(f"Verificando: {entry.title}")
    is_link_ok = check_link(entry.link)
    if is_link_ok:
        print(f"El enlace funciona: {entry.link}")
    else:
        print(f"El enlace está roto: {entry.link}")

# %%
import feedparser
import requests

def check_link(url):
    try:
        response = requests.head(url, allow_redirects=True, timeout=10)
        if response.status_code == 200:
            return True
        else:
            return False
    except requests.RequestException as e:
        print(f"Error al verificar el enlace {url}: {e}")
        return False

# Asegúrate de reemplazar 'tu-url-del-feed-aquí.com/rss' con la URL real de tu feed RSS
rss_url = "https://www.forbesargentina.com/"

# Parsear el feed
feed = feedparser.parse(rss_url)  # Aquí había un error, debe ser 'rss_url'

# Verificar cada enlace en las entradas del feed
for entry in feed.entries:
    print(f"Verificando: {entry.title}")
    is_link_ok = check_link(entry.link)
    if is_link_ok:
        print(f"El enlace funciona: {entry.link}")
    else:
        print(f"El enlace está roto: {entry.link}")

# %%
feed
# Out:
# {'bozo': 1,
#  'entries': [],
#  'feed': {'html': {'lang': 'es'},
#   'meta': {'name': 'viewport',
#    'content': 'width=device-width, initial-scale=1'},
#   'links': [{'rel': 'dns-prefetch',
#     'href': 'https://code.jquery.com',
#     'type': 'text/html'},
#    {'rel': 'dns-prefetch',
#     'href': 'https://fonts.googleapis.com',
#     'type': 'text/html'},
#    {'rel': 'dns-prefetch',
#     'href': 'https://cdnjs.cloudflare.com',
#     'type': 'text/html'},
#    {'rel': 'preconnect',
#     'href': 'https://fonts.googleapis.com',
#     'type': 'text/html'},
#    {'rel': 'preconnect',
#     'href': 'https://fonts.gstatic.com',
#     'crossorigin': 'crossorigin',
#     'type': 'text/html'},
#    {'rel': 'dns-prefetch',
#     'href': 'https://statics.forbesargentina.com/',
#     'type': 'text/html'},
#    {'rel': 'preconnect',
#     'href': 'https://statics.forbesargentina.com/',
#     'type': 'text/html'},
#    {'rel': 'preload',
#     'as': 'style',
# ...
